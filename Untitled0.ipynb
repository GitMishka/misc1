# %% [markdown]
# <a href="https://colab.research.google.com/github/GitMishka/2021_TSLAstock_Analysis-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
import io
df = pd.read_csv(io.BytesIO(uploaded['ds_salaries.csv']))
# Out:
#      <input type="file" id="files-9fd64ad1-208c-4a88-80ac-59845dd925ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fd64ad1-208c-4a88-80ac-59845dd925ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# group by employment_type and get mean salary
grouped = df.groupby('employment_type')['salary_in_usd'].mean()

# plot
plt.figure(figsize=(10, 6))
sns.barplot(x=grouped.index, y=grouped.values)
plt.title('Average Salary by Employment Type')
plt.xlabel('Employment Type')
plt.ylabel('Average Salary in USD')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by 'job_title' and compute the mean salary for each group
grouped = df.groupby('job_title')['salary_in_usd'].mean()

# Sort the values for better visualization
grouped = grouped.sort_values(ascending=False)

# Consider taking the top 10 or 20 job titles for visualization if there are too many unique job titles
# grouped = grouped[:20]

# Plot
plt.figure(figsize=(25, 16))
sns.barplot(x=grouped.values, y=grouped.index)  # Plotting values on the x-axis and job titles on the y-axis for better display
plt.title('Average Salary by Job Title')
plt.xlabel('Average Salary in USD')
plt.ylabel('Job Title')
plt.xticks(rotation=90)  # Rotating x-axis labels for better visibility if required
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ebc1178b01bf> in <cell line: 19>()
#      17 plt.xlabel('Average Salary in USD')
#      18 plt.ylabel('Job Title')
# ---> 19 for p in bar_plot.patches:
#      20     width = p.get_width()
#      21     plt.text(width,       # x-coordinate of text start
#
# NameError: name 'bar_plot' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by 'job_title' and compute the mean salary for each group
grouped = df.groupby('job_title')['salary_in_usd'].mean()

# Sort the values for better visualization
grouped = grouped.sort_values(ascending=False)

# Consider taking the top 10 or 20 job titles for visualization if there are too many unique job titles
# grouped = grouped[:20]

# Plot
plt.figure(figsize=(25, 16))
bar_plot = sns.barplot(x=grouped.values, y=grouped.index)  # Plotting values on the x-axis and job titles on the y-axis for better display
plt.title('Average Salary by Job Title')
plt.xlabel('Average Salary in USD')
plt.ylabel('Job Title')

# Add dollar amounts
for p in bar_plot.patches:
    width = p.get_width()
    plt.text(width,       # x-coordinate of text start
             p.get_y() + p.get_height() / 2,  # y-coordinate of text start
             '${:1.2f}'.format(width),  # text
             ha='left',   # horizontal alignment
             va='center')  # vertical alignment

plt.show()

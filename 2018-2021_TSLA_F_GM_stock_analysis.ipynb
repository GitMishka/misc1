# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('ggplot')
# %matplotlib inline
import pandas_datareader as web
import datetime

# %%
#getting data from yahoo api for tesla
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2021,1,1)
tsla = web.DataReader('TSLA','yahoo',start,end)
#tsla_Open=tsla[['Open']]
#tsla_dates=tsla.index.to_frame().reset_index(drop=True)
tsla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02   64.421997   62.200001   62.400002   64.106003  21761000.0
# 2018-01-03   65.050003   63.110001   64.199997   63.450001  22607500.0
# 2018-01-04   63.709999   61.136002   62.574001   62.924000  49731500.0
# 2018-01-05   63.448002   62.400002   63.324001   63.316002  22956000.0
# 2018-01-08   67.403999   63.099998   63.200001   67.281998  49297000.0
# ...                ...         ...         ...         ...         ...
# 2020-12-24  666.090027  641.000000  642.989990  661.770020  22865600.0
# 2020-12-28  681.400024  660.799988  674.510010  663.690002  32278600.0
# 2020-12-29  669.900024  655.000000  661.000000  665.989990  22910800.0
# 2020-12-30  696.599976  668.359985  672.000000  694.780029  42846000.0
# 2020-12-31  718.719971  691.119995  699.989990  705.669983  49570900.0
#
#              Adj Close
# Date
# 2018-01-02   64.106003
# 2018-01-03   63.450001
# 2018-01-04   62.924000
# 2018-01-05   63.316002
# 2018-01-08   67.281998
# ...                ...
# 2020-12-24  661.770020
# 2020-12-28  663.690002
# 2020-12-29  665.989990
# 2020-12-30  694.780029
# 2020-12-31  705.669983
#
# [756 rows x 6 columns]

# %%
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2021,1,1)
ford = web.DataReader('F','yahoo',start,end)
ford
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2018-01-02  12.66  12.50  12.52  12.66  20773300.0  10.842077
# 2018-01-03  12.80  12.67  12.68  12.76  29765600.0  10.927719
# 2018-01-04  13.04  12.77  12.78  12.98  37478200.0  11.116128
# 2018-01-05  13.22  13.04  13.06  13.20  46121900.0  11.304538
# 2018-01-08  13.22  13.11  13.21  13.15  33828300.0  11.261715
# ...           ...    ...    ...    ...         ...        ...
# 2020-12-24   9.02   8.80   9.01   8.86  27927000.0   8.860000
# 2020-12-28   8.98   8.86   8.92   8.89  38068400.0   8.890000
# 2020-12-29   8.93   8.78   8.93   8.82  37537900.0   8.820000
# 2020-12-30   8.92   8.81   8.83   8.86  38461900.0   8.860000
# 2020-12-31   8.86   8.78   8.84   8.79  40135300.0   8.790000
#
# [756 rows x 6 columns]

# %%
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2021,1,1)
gm = web.DataReader('GM','yahoo',start,end)
gm
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  41.869999  41.150002  41.240002  41.799999   6934600.0  38.072212
# 2018-01-03  42.950001  42.200001  42.209999  42.820000  14591600.0  39.001244
# 2018-01-04  44.250000  43.009998  43.090000  44.139999  17298700.0  40.203526
# 2018-01-05  44.639999  43.959999  44.500000  44.009998   9643300.0  40.085114
# 2018-01-08  44.590000  43.520000  44.040001  44.220001  13099600.0  40.276390
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24  42.200001  41.209999  42.060001  41.580002   7825400.0  41.580002
# 2020-12-28  42.189999  41.630001  42.000000  41.660000  10471400.0  41.660000
# 2020-12-29  42.130001  41.369999  41.889999  41.570000   7987700.0  41.570000
# 2020-12-30  42.200001  41.570000  41.650002  41.840000   6491900.0  41.840000
# 2020-12-31  41.799999  41.200001  41.759998  41.639999  11097900.0  41.639999
#
# [756 rows x 6 columns]

# %%
#getting data from excel 3 seperate sheets into one sheet, turning date column into index column
T = pd.read_csv('Tesla_Stock.csv',index_col=['Date'],parse_dates=True)
F = pd.read_csv('Ford_Stock.csv',index_col=['Date'],parse_dates=True)
G = pd.read_csv('GM_Stock.csv',index_col=['Date'],parse_dates=True)
ALL = pd.concat([T,F,G])

# %%
tsla['Open'].plot(label='Tesla',figsize=(16,6),title='Opening Prices')
gm['Open'].plot(label='GM',c='Blue')
ford['Open'].plot(label='Ford',c='Purple')
plt.legend();
# starting 2020 exponential growth in opening price can be observed in TSLA stock
# FORD & GM stocks remain relatively same

# %%
tsla['Volume'].plot(label='Tesla',figsize=(16,6),title='Volume Traded')
gm['Volume'].plot(label='GM',c='Blue')
ford['Volume'].plot(label='Ford',c='Purple')
plt.legend();
#TSLA and Ford stocks exprience much higher volume trades than GM, which remains steady
#in early 2020 & 2021 TSLA stock has significant rises in volume traded

# %%
tsla['Volume'].idxmax() #recorded day for highest volume traded for TSLA between 2018-2021
tsla['Volume'].max() #value
# Out:
# 304694000.0

# %%
ford['Volume'].idxmax() #recorded day for highest volume traded for F between 2018-2021
ford['Volume'].max() #value
# Out:
# 231800800.0

# %%
gm['Volume'].idxmax() #recorded day for highest volume traded for GM between 2018-2021
gm['Volume'].max() #value
# Out:
# 59937500.0

# %%
tsla['Total Traded'] = tsla['Open']*tsla['Volume']
ford['Total Traded'] = ford['Open']*ford['Volume']
gm['Total Traded'] = gm['Open']*gm['Volume']
tsla['Total Traded'].plot(label='TSLA',figsize=(16,6))
ford['Total Traded'].plot(label='F',c='Purple')
gm['Total Traded'].plot(label='GM',c='Blue')
plt.legend();
#loose estimation of money traded

# %%
tsla['Total Traded'].idxmax()
# Out:
# Timestamp('2020-12-18 00:00:00')

# %%
tsla['Total Traded'].idxmax()
# Out:
# Timestamp('2018-01-17 00:00:00')

# %%
gm['Total Traded'].idxmax()
# Out:
# Timestamp('2018-05-31 00:00:00')

# %%
tsla['MA20'] = tsla['Open'].rolling(20).mean() #20 day moving average

# %%
tsla['MA50'] = tsla['Open'].rolling(50).mean() #50 day moving average
tsla[['Open','MA20','MA50']].plot(figsize=(16,6));

# %%
from pandas.plotting import scatter_matrix

# %%
all_stx = pd.concat([tsla['Open'],gm['Open'],ford['Open']],axis=1)

# %%
all_stx.columns = ['Tesla','GM','Ford']

# %%
all_stx
# Out:
#                  Tesla      GM      Ford
# Date
# 2018-01-02   62.400002  41.240002  12.52
# 2018-01-03   64.199997  42.209999  12.68
# 2018-01-04   62.574001  43.090000  12.78
# 2018-01-05   63.324001  44.500000  13.06
# 2018-01-08   63.200001  44.040001  13.21
# ...                ...        ...    ...
# 2020-12-24  642.989990  42.060001   9.01
# 2020-12-28  674.510010  42.000000   8.92
# 2020-12-29  661.000000  41.889999   8.93
# 2020-12-30  672.000000  41.650002   8.83
# 2020-12-31  699.989990  41.759998   8.84
#
# [756 rows x 3 columns]

# %%
scatter_matrix(all_stx,figsize=(6,6),alpha=.2,hist_kwds={'bins':50});

# %%
#TSLA's relationship to GM & FORD is weak
#Ford & GM relationship is strong

# %%
tsla['returns'] = (tsla['Close']/tsla['Close'].shift(1)) -1

# %%
tsla['Close']
# Out:
# Date
# 2018-01-02     64.106003
# 2018-01-03     63.450001
# 2018-01-04     62.924000
# 2018-01-05     63.316002
# 2018-01-08     67.281998
#                  ...
# 2020-12-24    661.770020
# 2020-12-28    663.690002
# 2020-12-29    665.989990
# 2020-12-30    694.780029
# 2020-12-31    705.669983
# Name: Close, Length: 756, dtype: float64

# %%
tsla['Close'].shift(1)
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03     64.106003
# 2018-01-04     63.450001
# 2018-01-05     62.924000
# 2018-01-08     63.316002
#                  ...
# 2020-12-24    645.979980
# 2020-12-28    661.770020
# 2020-12-29    663.690002
# 2020-12-30    665.989990
# 2020-12-31    694.780029
# Name: Close, Length: 756, dtype: float64

# %%
tsla['returns'] = tsla['Close'].pct_change(1) 
#same thing as tsla['returns'] = (tsla['Close']/tsla['Close'].shift(1)) -1

# %%
tsla['returns']
# Out:
# Date
# 2018-01-02         NaN
# 2018-01-03   -0.010233
# 2018-01-04   -0.008290
# 2018-01-05    0.006230
# 2018-01-08    0.062638
#                 ...
# 2020-12-24    0.024444
# 2020-12-28    0.002901
# 2020-12-29    0.003465
# 2020-12-30    0.043229
# 2020-12-31    0.015674
# Name: returns, Length: 756, dtype: float64

# %%
ford['returns'] = ford['Close'].pct_change(1) 
gm['returns'] = gm['Close'].pct_change(1)

# %%
tsla.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2018-01-02  64.421997  62.200001  62.400002  64.106003  21761000.0  64.106003
# 2018-01-03  65.050003  63.110001  64.199997  63.450001  22607500.0  63.450001
# 2018-01-04  63.709999  61.136002  62.574001  62.924000  49731500.0  62.924000
# 2018-01-05  63.448002  62.400002  63.324001  63.316002  22956000.0  63.316002
# 2018-01-08  67.403999  63.099998  63.200001  67.281998  49297000.0  67.281998
#
#             Total Traded  MA20  MA50   returns
# Date
# 2018-01-02  1.357886e+09   NaN   NaN       NaN
# 2018-01-03  1.451401e+09   NaN   NaN -0.010233
# 2018-01-04  3.111899e+09   NaN   NaN -0.008290
# 2018-01-05  1.453666e+09   NaN   NaN  0.006230
# 2018-01-08  3.115570e+09   NaN   NaN  0.062638

# %%
tsla['returns'].hist(bins=100, figsize=(16,6));
# Out:
# <AxesSubplot:>

# %%
gm['returns'].hist(bins=100,figsize=(16,6),color='Purple');
# Out:
# <AxesSubplot:>

# %%
ford['returns'].hist(bins=100,figsize=(16,6),color='Blue');
# Out:
# <AxesSubplot:>

# %%
ford['returns'].hist(bins=100,figsize=(16,6),color='Blue',label='Ford',alpha=.5)
gm['returns'].hist(bins=100,figsize=(16,6),color='Purple',label='GM',alpha=.5)
tsla['returns'].hist(bins=100,figsize=(16,6),color='Red',label='Tesla',alpha=.5)
plt.legend();
#General volatility between 3 stocks, TSLA stock is by far most violilce, GM more volatile than F.

# %%
tsla['returns'].plot(kind='kde',label='TSLA',figsize=(10,8))
ford['returns'].plot(kind='kde',label='Ford',figsize=(10,8))
gm['returns'].plot(kind='kde',label='GM',figsize=(10,8))
plt.legend();
#Ford stock is most stable

# %%
box_df=pd.concat([tsla['returns'],ford['returns'],gm['returns']],axis=1)
box_df.columns = ['TSLA returns','F returns','GM returns']
box_df.plot(kind='box',figsize=(16,6))
# Out:
# <AxesSubplot:>

# %%
scatter_matrix(box_df,figsize=(8,8),alpha=.2,hist_kwds={'bins':100});

# %%
box_df.plot(kind='scatter',x='F returns',y='TSLA returns',alpha=.5,figsize=(16,6),c='purple')
# Out:
# <AxesSubplot:xlabel='F returns', ylabel='TSLA returns'>

# %%
#cumulative daily return

# %%
tsla['Cumulative Return'] = (1+ tsla['returns']).cumprod()
tsla
#if I invested on 2018-01-02 and kept my investment my cumulative returns would rise over x10 times
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-01-02   64.421997   62.200001   62.400002   64.106003  21761000.0
# 2018-01-03   65.050003   63.110001   64.199997   63.450001  22607500.0
# 2018-01-04   63.709999   61.136002   62.574001   62.924000  49731500.0
# 2018-01-05   63.448002   62.400002   63.324001   63.316002  22956000.0
# 2018-01-08   67.403999   63.099998   63.200001   67.281998  49297000.0
# ...                ...         ...         ...         ...         ...
# 2020-12-24  666.090027  641.000000  642.989990  661.770020  22865600.0
# 2020-12-28  681.400024  660.799988  674.510010  663.690002  32278600.0
# 2020-12-29  669.900024  655.000000  661.000000  665.989990  22910800.0
# 2020-12-30  696.599976  668.359985  672.000000  694.780029  42846000.0
# 2020-12-31  718.719971  691.119995  699.989990  705.669983  49570900.0
#
#              Adj Close  Total Traded        MA20        MA50   returns  \
# Date
# 2018-01-02   64.106003  1.357886e+09         NaN         NaN       NaN
# 2018-01-03   63.450001  1.451401e+09         NaN         NaN -0.010233
# 2018-01-04   62.924000  3.111899e+09         NaN         NaN -0.008290
# 2018-01-05   63.316002  1.453666e+09         NaN         NaN  0.006230
# 2018-01-08   67.281998  3.115570e+09         NaN         NaN  0.062638
# ...                ...           ...         ...         ...       ...
# 2020-12-24  661.770020  1.470235e+10  618.448004  512.179603  0.024444
# 2020-12-28  663.690002  2.177224e+10  623.115506  516.663603  0.002901
# 2020-12-29  665.989990  1.514404e+10  626.055005  520.794803  0.003465
# 2020-12-30  694.780029  2.879251e+10  629.775504  525.310003  0.043229
# 2020-12-31  705.669983  3.469913e+10  636.953003  530.674803  0.015674
#
#             Cumulative Return
# Date
# 2018-01-02                NaN
# 2018-01-03           0.989767
# 2018-01-04           0.981562
# 2018-01-05           0.987677
# 2018-01-08           1.049543
# ...                       ...
# 2020-12-24          10.323059
# 2020-12-28          10.353009
# 2020-12-29          10.388887
# 2020-12-30          10.837987
# 2020-12-31          11.007861
#
# [756 rows x 11 columns]

# %%
ford['Cumulative Return'] = (1+ ford['returns']).cumprod()
ford
#if I did same thing for Ford I would actually lose cumulative returns
# Out:
#              High    Low   Open  Close      Volume  Adj Close  Total Traded  \
# Date
# 2018-01-02  12.66  12.50  12.52  12.66  20773300.0  10.842077  2.600817e+08
# 2018-01-03  12.80  12.67  12.68  12.76  29765600.0  10.927719  3.774278e+08
# 2018-01-04  13.04  12.77  12.78  12.98  37478200.0  11.116128  4.789714e+08
# 2018-01-05  13.22  13.04  13.06  13.20  46121900.0  11.304538  6.023520e+08
# 2018-01-08  13.22  13.11  13.21  13.15  33828300.0  11.261715  4.468718e+08
# ...           ...    ...    ...    ...         ...        ...           ...
# 2020-12-24   9.02   8.80   9.01   8.86  27927000.0   8.860000  2.516223e+08
# 2020-12-28   8.98   8.86   8.92   8.89  38068400.0   8.890000  3.395701e+08
# 2020-12-29   8.93   8.78   8.93   8.82  37537900.0   8.820000  3.352135e+08
# 2020-12-30   8.92   8.81   8.83   8.86  38461900.0   8.860000  3.396186e+08
# 2020-12-31   8.86   8.78   8.84   8.79  40135300.0   8.790000  3.547961e+08
#
#              returns  Cumulative Return
# Date
# 2018-01-02       NaN                NaN
# 2018-01-03  0.007899           1.007899
# 2018-01-04  0.017241           1.025276
# 2018-01-05  0.016949           1.042654
# 2018-01-08 -0.003788           1.038705
# ...              ...                ...
# 2020-12-24 -0.014461           0.699842
# 2020-12-28  0.003386           0.702212
# 2020-12-29 -0.007874           0.696682
# 2020-12-30  0.004535           0.699842
# 2020-12-31 -0.007901           0.694313
#
# [756 rows x 9 columns]

# %%
gm['Cumulative Return'] = (1+ gm['returns']).cumprod()
gm
#I would lose cumulative returns if I invested into GM stock, but not as much as Ford stock
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  \
# Date
# 2018-01-02  41.869999  41.150002  41.240002  41.799999   6934600.0  38.072212
# 2018-01-03  42.950001  42.200001  42.209999  42.820000  14591600.0  39.001244
# 2018-01-04  44.250000  43.009998  43.090000  44.139999  17298700.0  40.203526
# 2018-01-05  44.639999  43.959999  44.500000  44.009998   9643300.0  40.085114
# 2018-01-08  44.590000  43.520000  44.040001  44.220001  13099600.0  40.276390
# ...               ...        ...        ...        ...         ...        ...
# 2020-12-24  42.200001  41.209999  42.060001  41.580002   7825400.0  41.580002
# 2020-12-28  42.189999  41.630001  42.000000  41.660000  10471400.0  41.660000
# 2020-12-29  42.130001  41.369999  41.889999  41.570000   7987700.0  41.570000
# 2020-12-30  42.200001  41.570000  41.650002  41.840000   6491900.0  41.840000
# 2020-12-31  41.799999  41.200001  41.759998  41.639999  11097900.0  41.639999
#
#             Total Traded   returns  Cumulative Return
# Date
# 2018-01-02  2.859829e+08       NaN                NaN
# 2018-01-03  6.159114e+08  0.024402           1.024402
# 2018-01-04  7.454010e+08  0.030827           1.055981
# 2018-01-05  4.291268e+08 -0.002945           1.052871
# 2018-01-08  5.769064e+08  0.004772           1.057895
# ...                  ...       ...                ...
# 2020-12-24  3.291363e+08 -0.020495           0.994737
# 2020-12-28  4.397988e+08  0.001924           0.996651
# 2020-12-29  3.346047e+08 -0.002160           0.994498
# 2020-12-30  2.703876e+08  0.006495           1.000957
# 2020-12-31  4.634483e+08 -0.004780           0.996172
#
# [756 rows x 9 columns]

# %%
tsla['Cumulative Return'].plot(label='TSLA',figsize=(16,8),c='Red')
ford['Cumulative Return'].plot(label='F',figsize=(16,8),c='Blue')
gm['Cumulative Return'].plot(label='GM',figsize=(16,8),c='Purple')
plt.legend();
#TSLA promeses exponential cumulative return from 2018 to 2021 time frame
#ford has lowest cumu
